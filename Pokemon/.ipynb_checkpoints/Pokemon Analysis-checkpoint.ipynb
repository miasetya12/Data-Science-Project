# %% [markdown]
# # Pokemon Analysis

# %% [markdown]
# ## Dataset Information
# This dataset comprises of sales transactions captured at a retail store. It’s a classic dataset to explore and expand your feature engineering skills and day to day understanding from multiple shopping experiences. This is a regression problem. The dataset has 550,069 rows and 12 columns.
# The dataset can be access in: https://drive.google.com/file/d/1-Sc7_q52hxhKMEe-nyly_HXxbRzPpzWT/view
#
# Problem: Predict purchase amount

# %% [markdown]
# # Import Modules

# %%
# !pip install seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# C:\Users\miase\AppData\Local\Temp\ipykernel_19716\3618565165.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Loading Dataset

# %%
#loading the dataset
df=pd.read_csv('Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.shape
# Out:
# (800, 13)

# %%
# statistical info
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# find unique values
df.apply(lambda x: len(x.unique()))
# Out:
# #             721
# Name          800
# Type 1         18
# Type 2         19
# Total         200
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
plt.figure(figsize=(5, 6))
ax = sns.countplot(x='Generation', data=df, order=df['Generation'].value_counts().index, )
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(20, 15))

# Count plot for 'Age'
t1 = sns.countplot(x='Type 1', data=df, ax=axes[0])
for p in t1.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
axes[0].set_title('Count Plot of Type 1')

# Count plot for 'Age'
t2=sns.countplot(x='Type 2', data=df, ax=axes[1])
for p in t2.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
axes[1].set_title('Count Plot of Type 2')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Preprocessing the dataset
# 1. Fix missing value
# 2. Fix Stay_In_Current_City_Years ("+")
# 3. Encoding values using dict
# 4. Use one hot encoding

# %%
# Check missing value
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
# Fix the missing value in , fillna with None
df['Type 2'].fillna(None, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Fix the missing value in , fillna with None
# ----> 2 df['Type 2'].fillna(None, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:7287, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7280         if ctr <= ref_count:
#    7281             warnings.warn(
#    7282                 _chained_assignment_warning_method_msg,
#    7283                 FutureWarning,
#    7284                 stacklevel=2,
#    7285             )
# -> 7287 value, method = validate_fillna_kwargs(value, method)
#    7288 if method is not None:
#    7289     warnings.warn(
#    7290         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7291         "will raise in a future version. Use obj.ffill() or obj.bfill() "
# ...
